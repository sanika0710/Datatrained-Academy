# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv('space_server.csv')

# %%
df.head()
# Out:
#           objid          ra       dec         u         g         r         i  \
# 0  1.237650e+18  183.531326  0.089693  19.47406  17.04240  15.94699  15.50342
# 1  1.237650e+18  183.598371  0.135285  18.66280  17.21449  16.67637  16.48922
# 2  1.237650e+18  183.680207  0.126185  19.38298  18.19169  17.47428  17.08732
# 3  1.237650e+18  183.870529  0.049911  17.76536  16.60272  16.16116  15.98233
# 4  1.237650e+18  183.883288  0.102557  17.55025  16.26342  16.43869  16.55492
#
#           z  run  rerun  camcol  field     specobjid   class  redshift  plate  \
# 0  15.22531  752    301       4    267  3.722360e+18    STAR -0.000009   3306
# 1  16.39150  752    301       4    267  3.638140e+17    STAR -0.000055    323
# 2  16.80125  752    301       4    268  3.232740e+17  GALAXY  0.123111    287
# 3  15.90438  752    301       4    269  3.722370e+18    STAR -0.000111   3306
# 4  16.61326  752    301       4    269  3.722370e+18    STAR  0.000590   3306
#
#      mjd  fiberid
# ...

# %%
df.shape
# Out:
# (10000, 18)

# %%
df.columns
# Out:
# Index(['objid', 'ra', 'dec', 'u', 'g', 'r', 'i', 'z', 'run', 'rerun', 'camcol',
#        'field', 'specobjid', 'class', 'redshift', 'plate', 'mjd', 'fiberid'],
#       dtype='object')

# %%
df.nunique()
# Out:
# objid            1
# ra           10000
# dec          10000
# u             9730
# g             9817
# r             9852
# i             9890
# z             9896
# run             23
# rerun            1
# camcol           6
# field          703
# specobjid     6349
# class            3
# redshift      9637
# plate          487
# mjd            355
# fiberid        892
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 18 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   objid      10000 non-null  float64
#  1   ra         10000 non-null  float64
#  2   dec        10000 non-null  float64
#  3   u          10000 non-null  float64
#  4   g          10000 non-null  float64
#  5   r          10000 non-null  float64
#  6   i          10000 non-null  float64
#  7   z          10000 non-null  float64
#  8   run        10000 non-null  int64
#  9   rerun      10000 non-null  int64
#  10  camcol     10000 non-null  int64
#  11  field      10000 non-null  int64
#  12  specobjid  10000 non-null  float64
#  13  class      10000 non-null  object
#  14  redshift   10000 non-null  float64
#  15  plate      10000 non-null  int64
#  16  mjd        10000 non-null  int64
#  17  fiberid    10000 non-null  int64
# dtypes: float64(10), int64(7), object(1)
# ...

# %%
df.isnull().sum()
# Out:
# objid        0
# ra           0
# dec          0
# u            0
# g            0
# r            0
# i            0
# z            0
# run          0
# rerun        0
# camcol       0
# field        0
# specobjid    0
# class        0
# redshift     0
# plate        0
# mjd          0
# fiberid      0
# dtype: int64

# %%
df['class'].value_counts()
# Out:
# GALAXY    4998
# STAR      4152
# QSO        850
# Name: class, dtype: int64

# %%
df['class'].value_counts().plot.bar()

# %%
df= pd.DataFrame(data = np.random.random(size=(4,18)), columns = ['objid', 'ra', 'dec', 'u', 'g', 'r', 'i', 'z', 'run', 'rerun', 'camcol',
       'field', 'specobjid', 'class', 'redshift', 'plate', 'mjd', 'fiberid'])
df.boxplot()

# %%
sns.distplot(df['objid'])

# %%
sns.distplot(df['ra'])

# %%
sns.distplot(df['dec'])

# %%
sns.distplot(df['u'])

# %%
sns.distplot(df['g'])

# %%
sns.distplot(df['r'])

# %%
sns.distplot(df['i'])

# %%
sns.distplot(df['z'])

# %%
sns.distplot(df['run'])

# %%
sns.distplot(df['rerun'])

# %%
sns.distplot(df['camcol'])

# %%
sns.distplot(df['field'])

# %%
sns.distplot(df['specobjid'])

# %%
sns.distplot(df['redshift'])

# %%
sns.distplot(df['plate'])

# %%
sns.distplot(df['mjd'])

# %%
sns.distplot(df['fiberid'])

# %%
df.drop(['objid', 'run', 'rerun', 'camcol', 'field', 'specobjid'],inplace=True,axis=1)

# %%
sns.pairplot(df)

# %%
df.head()
# Out:
#          ra       dec         u         g         r         i         z  \
# 0  0.389479  0.217174  0.147593  0.007998  0.653670  0.550878  0.388756
# 1  0.827174  0.602647  0.396643  0.562231  0.368698  0.225475  0.477012
# 2  0.283698  0.900882  0.398133  0.879698  0.168514  0.474205  0.212587
# 3  0.315996  0.644049  0.367453  0.337075  0.098628  0.015368  0.942017
#
#       class  redshift     plate       mjd   fiberid
# 0  0.180110  0.921239  0.541231  0.687429  0.536928
# 1  0.974810  0.877561  0.714290  0.234771  0.003746
# 2  0.057395  0.606492  0.993724  0.417588  0.797570
# 3  0.426273  0.898138  0.349348  0.562351  0.480330

# %%
df_corr=df.corr
df_corr
# Out:
# <bound method DataFrame.corr of          ra       dec         u         g         r         i         z  \
# 0  0.389479  0.217174  0.147593  0.007998  0.653670  0.550878  0.388756
# 1  0.827174  0.602647  0.396643  0.562231  0.368698  0.225475  0.477012
# 2  0.283698  0.900882  0.398133  0.879698  0.168514  0.474205  0.212587
# 3  0.315996  0.644049  0.367453  0.337075  0.098628  0.015368  0.942017
#
#       class  redshift     plate       mjd   fiberid
# 0  0.180110  0.921239  0.541231  0.687429  0.536928
# 1  0.974810  0.877561  0.714290  0.234771  0.003746
# 2  0.057395  0.606492  0.993724  0.417588  0.797570
# 3  0.426273  0.898138  0.349348  0.562351  0.480330  >

# %%
df.skew()
# Out:
# ra          1.822639
# dec        -0.667270
# u          -1.920552
# g          -0.041446
# r           0.936189
# i          -0.515756
# z           1.254516
# class       1.235129
# redshift   -1.912244
# plate       0.411926
# mjd        -0.359575
# fiberid    -0.934787
# dtype: float64

# %%
skew=(df.columns)
for col in skew :
    if df.skew().loc[col]>0.55:
        df[col] = np.log1p(df[col])

# %%
df.skew()
# Out:
# ra          1.762748
# dec        -0.667270
# u          -1.920552
# g          -0.041446
# r           0.742728
# i          -0.515756
# z           0.969878
# class       0.931860
# redshift   -1.912244
# plate       0.411926
# mjd        -0.359575
# fiberid    -0.934787
# dtype: float64

# %%
from sklearn.decomposition import PCA
# Principal Component Analysis
pca = PCA(n_components=3)
ugriz = pca.fit_transform(df[['u', 'g', 'r', 'i', 'z']])

# %%
df = pd.concat((df, pd.DataFrame(ugriz)), axis=1)
df.rename({0: 'PCA_1', 1: 'PCA_2', 2: 'PCA_3'}, axis=1, inplace = True)
df.drop(['u', 'g', 'r', 'i', 'z'], axis=1, inplace=True)
df.head()
# Out:
#          ra       dec     class  redshift     plate       mjd   fiberid  \
# 0  0.328929  0.217174  0.165608  0.921239  0.541231  0.687429  0.536928
# 1  0.602770  0.602647  0.680472  0.877561  0.714290  0.234771  0.003746
# 2  0.249745  0.900882  0.055809  0.606492  0.993724  0.417588  0.797570
# 3  0.274594  0.644049  0.355065  0.898138  0.349348  0.562351  0.480330
#
#       PCA_1     PCA_2     PCA_3
# 0  0.534012 -0.233439 -0.015934
# 1 -0.116285  0.038941  0.116651
# 2 -0.448647 -0.256844 -0.052522
# 3  0.030920  0.451342 -0.048194

# %%
x=df.drop(['class'],axis=1)
y=df['class']

# %%
column = ['class']
le = LabelEncoder()
for i in column:
    df[i] = le.fit_transform(df[i].astype(str))

print(df.dtypes)
# Out:
# ra          float64
# dec         float64
# class         int32
# redshift    float64
# plate       float64
# mjd         float64
# fiberid     float64
# PCA_1       float64
# PCA_2       float64
# PCA_3       float64
# dtype: object

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split( x, y, test_size = 0.3, random_state = 43)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

model=[LogisticRegression(),GaussianNB(),SVC(),DecisionTreeClassifier()]

for m in model:
    m.fit(x_train,y_train)
    m.score(x_train,y_train)
    predm=m.predict(x_test)
    print('Accuracy score of ',m, 'is:')
    print(accuracy_score(y_test,predm))
    print(confusion_matrix(y_test,predm))
    print(classification_report(y_test,predm))
    print('\n')
# Out:
# Accuracy score of  LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False) is:
# 0.0
# [[0 1 0]
#  [0 0 0]
#  [0 1 0]]
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       1.0
#            2       0.00      0.00      0.00       0.0
#            3       0.00      0.00      0.00       1.0
#
#     accuracy                           0.00       2.0
#    macro avg       0.00      0.00      0.00       2.0
# weighted avg       0.00      0.00      0.00       2.0
#
#
#
# Accuracy score of  GaussianNB(priors=None, var_smoothing=1e-09) is:
# 0.0
# [[0 1 0]
#  [0 0 0]
#  [0 1 0]]
#               precision    recall  f1-score   support
#
# ...

# %%
from sklearn.externals import joblib
#save the model 
joblib.dump(m, 'Project8.obj')
# Out:
# ['Project8.obj']

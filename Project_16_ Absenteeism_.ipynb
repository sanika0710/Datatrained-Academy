# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_excel(r'C:\Users\SANIKA\Documents\Absenteeism_at_work.xlsx')

# %%
df.head(20)
# Out:
#     ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 0   11                  26                 7                3        1
# 1   36                   0                 7                3        1
# 2    3                  23                 7                4        1
# 3    7                   7                 7                5        1
# 4   11                  23                 7                5        1
# 5    3                  23                 7                6        1
# 6   10                  22                 7                6        1
# 7   20                  23                 7                6        1
# 8   14                  19                 7                2        1
# 9    1                  22                 7                2        1
# 10  20                   1                 7                2        1
# 11  20                   1                 7                3        1
# ...

# %%
df.shape
# Out:
# (740, 21)

# %%
df.columns
# Out:
# Index(['ID', 'Reason for absence', 'Month of absence', 'Day of the week',
#        'Seasons', 'Transportation expense', 'Distance from Residence to Work',
#        'Service time', 'Age', 'Work load Average/day ', 'Hit target',
#        'Disciplinary failure', 'Education', 'Son', 'Social drinker',
#        'Social smoker', 'Pet', 'Weight', 'Height', 'Body mass index',
#        'Absenteeism time in hours'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 740 entries, 0 to 739
# Data columns (total 21 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   ID                               740 non-null    int64
#  1   Reason for absence               740 non-null    int64
#  2   Month of absence                 740 non-null    int64
#  3   Day of the week                  740 non-null    int64
#  4   Seasons                          740 non-null    int64
#  5   Transportation expense           740 non-null    int64
#  6   Distance from Residence to Work  740 non-null    int64
#  7   Service time                     740 non-null    int64
#  8   Age                              740 non-null    int64
#  9   Work load Average/day            740 non-null    int64
#  10  Hit target                       740 non-null    int64
#  11  Disciplinary failure             740 non-null    int64
# ...

# %%
df.isnull().sum()
# Out:
# ID                                 0
# Reason for absence                 0
# Month of absence                   0
# Day of the week                    0
# Seasons                            0
# Transportation expense             0
# Distance from Residence to Work    0
# Service time                       0
# Age                                0
# Work load Average/day              0
# Hit target                         0
# Disciplinary failure               0
# Education                          0
# Son                                0
# Social drinker                     0
# Social smoker                      0
# Pet                                0
# Weight                             0
# Height                             0
# Body mass index                    0
# Absenteeism time in hours          0
# dtype: int64

# %%
df.describe()
# Out:
#                ID  Reason for absence  Month of absence  Day of the week  \
# count  740.000000          740.000000        740.000000       740.000000
# mean    18.017568           19.216216          6.324324         3.914865
# std     11.021247            8.433406          3.436287         1.421675
# min      1.000000            0.000000          0.000000         2.000000
# 25%      9.000000           13.000000          3.000000         3.000000
# 50%     18.000000           23.000000          6.000000         4.000000
# 75%     28.000000           26.000000          9.000000         5.000000
# max     36.000000           28.000000         12.000000         6.000000
#
#           Seasons  Transportation expense  Distance from Residence to Work  \
# count  740.000000              740.000000                       740.000000
# mean     2.544595              221.329730                        29.631081
# std      1.111831               66.952223                        14.836788
# ...

# %%
df.nunique()
# Out:
# ID                                 36
# Reason for absence                 28
# Month of absence                   13
# Day of the week                     5
# Seasons                             4
# Transportation expense             24
# Distance from Residence to Work    25
# Service time                       18
# Age                                22
# Work load Average/day              38
# Hit target                         13
# Disciplinary failure                2
# Education                           4
# Son                                 5
# Social drinker                      2
# Social smoker                       2
# Pet                                 6
# Weight                             26
# Height                             14
# Body mass index                    17
# Absenteeism time in hours          19
# dtype: int64

# %%
df_cor=df.corr()

# %%
plt.figure(figsize=(20,20))
sns.heatmap(df_cor,annot=True)

# %%
df.columns
# Out:
# Index(['ID', 'Reason for absence', 'Month of absence', 'Day of the week',
#        'Seasons', 'Transportation expense', 'Distance from Residence to Work',
#        'Service time', 'Age', 'Work load Average/day ', 'Hit target',
#        'Disciplinary failure', 'Education', 'Son', 'Social drinker',
#        'Social smoker', 'Pet', 'Weight', 'Height', 'Body mass index',
#        'Absenteeism time in hours'],
#       dtype='object')

# %%
sns.countplot(df['Absenteeism time in hours'])

# %%
sns.countplot(df['Absenteeism time in hours'])

# %%
sns.countplot(df['Reason for absence'])

# %%
sns.countplot(df['Month of absence'])

# %%
sns.countplot(df['Day of the week'])

# %%
sns.countplot(df['Seasons'])

# %%
plt.figure(figsize=(10,5))
sns.countplot(df['Transportation expense'])

# %%
sns.countplot(df['Distance from Residence to Work'])

# %%
sns.countplot(df['Service time'])

# %%
sns.countplot(df['Age'])

# %%
plt.figure(figsize=(24,5))
sns.countplot(df['Work load Average/day '])

# %%
sns.countplot(df['Hit target'])

# %%
sns.countplot(df['Disciplinary failure'])

# %%
sns.countplot(df['Education'])

# %%
sns.countplot(df['Son'])

# %%
sns.countplot(df['Social drinker'])

# %%
sns.countplot(df['Social smoker'],data=df)

# %%
sns.countplot(df['Pet'],data=df)

# %%
sns.countplot(df['Weight'])

# %%
sns.countplot(df['Height'])

# %%
sns.countplot(df['Body mass index'])

# %%
sns.barplot(x='Body mass index',y='Absenteeism time in hours',data=df)

# %%
sns.barplot(x='Height',y='Absenteeism time in hours',data=df)

# %%
sns.barplot(x='Weight',y='Absenteeism time in hours',data=df)

# %%
sns.barplot(x='Pet',y='Absenteeism time in hours',data=df)

# %%
sns.barplot(x='Social smoker',y='Absenteeism time in hours',data=df)

# %%
sns.barplot(x='Social drinker',y='Absenteeism time in hours',data=df)

# %%
sns.barplot(x='Son',y='Absenteeism time in hours',data=df)

# %%
sns.barplot(x='Education',y='Absenteeism time in hours',data=df)

# %%
sns.barplot(x='Disciplinary failure',y='Absenteeism time in hours',data=df)

# %%
sns.barplot(x='Hit target',y='Absenteeism time in hours',data=df)

# %%
sns.barplot(x='Work load Average/day ',y='Absenteeism time in hours',data=df)

# %%
sns.barplot(x='Age',y='Absenteeism time in hours',data=df)

# %%
sns.barplot(x='Service time',y='Absenteeism time in hours',data=df)

# %%
sns.barplot(x='Distance from Residence to Work',y='Absenteeism time in hours',data=df)

# %%
sns.barplot(x='Transportation expense',y='Absenteeism time in hours',data=df)

# %%
sns.barplot(x='Seasons',y='Absenteeism time in hours',data=df)

# %%
sns.barplot(x='Day of the week',y='Absenteeism time in hours',data=df)

# %%
sns.barplot(x='Month of absence',y='Absenteeism time in hours',data=df)

# %%
sns.barplot(x='Reason for absence',y='Absenteeism time in hours',data=df)

# %%
df.plot(kind='box',subplots = True,layout=(4,7),figsize = (15,10))
# Out:
# ID                                     AxesSubplot(0.125,0.71587;0.0945122x0.16413)
# Reason for absence                  AxesSubplot(0.238415,0.71587;0.0945122x0.16413)
# Month of absence                    AxesSubplot(0.351829,0.71587;0.0945122x0.16413)
# Day of the week                     AxesSubplot(0.465244,0.71587;0.0945122x0.16413)
# Seasons                             AxesSubplot(0.578659,0.71587;0.0945122x0.16413)
# Transportation expense              AxesSubplot(0.692073,0.71587;0.0945122x0.16413)
# Distance from Residence to Work     AxesSubplot(0.805488,0.71587;0.0945122x0.16413)
# Service time                          AxesSubplot(0.125,0.518913;0.0945122x0.16413)
# Age                                AxesSubplot(0.238415,0.518913;0.0945122x0.16413)
# Work load Average/day              AxesSubplot(0.351829,0.518913;0.0945122x0.16413)
# Hit target                         AxesSubplot(0.465244,0.518913;0.0945122x0.16413)
# ...

# %% [markdown]
# From Univariate Analysis and Bivariate analysis, there is certain skewness and outliers present

# %%
df.skew()
sns.distplot(df)

# %%
df=df**(2)
sns.distplot(df)

# %%
df=df**(3)
sns.distplot(df)

# %%
df.head()
# Out:
#                     ID   Reason for absence     Month of absence  \
# 0  1443930027461590561 -3494536315548991488  7113790643470898241
# 1  3873377154515337216                    0  7113790643470898241
# 2         282429536481 -8560217158519514431  7113790643470898241
# 3  7113790643470898241  7113790643470898241  7113790643470898241
# 4  1443930027461590561 -8560217158519514431  7113790643470898241
#
#      Day of the week  Seasons  Transportation expense  \
# 0       282429536481        1      410158792346528513
# 1       282429536481        1     8317924896982171648
# 2    281474976710656        1    -2404719364370111903
# 3  59604644775390625        1    -2517515751437942079
# 4  59604644775390625        1      410158792346528513
#
#    Distance from Residence to Work         Service time                  Age  \
# 0              3873377154515337216 -5103570345589621663  5076035615952753409
# 1             -5103570345589621663 -5766089433837207552  8120319428677074944
# ...

# %%
df.dtypes
# Out:
# ID                                 int64
# Reason for absence                 int64
# Month of absence                   int64
# Day of the week                    int64
# Seasons                            int64
# Transportation expense             int64
# Distance from Residence to Work    int64
# Service time                       int64
# Age                                int64
# Work load Average/day              int64
# Hit target                         int64
# Disciplinary failure               int64
# Education                          int64
# Son                                int64
# Social drinker                     int64
# Social smoker                      int64
# Pet                                int64
# Weight                             int64
# Height                             int64
# Body mass index                    int64
# Absenteeism time in hours          int64
# dtype: object

# %%
df.columns
# Out:
# Index(['ID', 'Reason for absence', 'Month of absence', 'Day of the week',
#        'Seasons', 'Transportation expense', 'Distance from Residence to Work',
#        'Service time', 'Age', 'Work load Average/day ', 'Hit target',
#        'Disciplinary failure', 'Education', 'Son', 'Social drinker',
#        'Social smoker', 'Pet', 'Weight', 'Height', 'Body mass index',
#        'Absenteeism time in hours'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder
column = ['ID', 'Reason for absence', 'Month of absence', 'Day of the week',
       'Seasons', 'Transportation expense', 'Distance from Residence to Work',
       'Service time', 'Age', 'Work load Average/day ', 'Hit target',
       'Disciplinary failure', 'Education', 'Son', 'Social drinker',
       'Social smoker', 'Pet', 'Weight', 'Height', 'Body mass index',
       'Absenteeism time in hours']
le = LabelEncoder()
for i in column:
    df[i] = le.fit_transform(df[i].astype(str))

print(df.dtypes)
# Out:
# ID                                 int32
# Reason for absence                 int32
# Month of absence                   int32
# Day of the week                    int32
# Seasons                            int32
# Transportation expense             int32
# Distance from Residence to Work    int32
# Service time                       int32
# Age                                int32
# Work load Average/day              int32
# Hit target                         int32
# Disciplinary failure               int32
# Education                          int32
# Son                                int32
# Social drinker                     int32
# Social smoker                      int32
# Pet                                int32
# Weight                             int32
# Height                             int32
# Body mass index                    int32
# Absenteeism time in hours          int32
# dtype: object

# %%
df.head()
# Out:
#    ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 0  18                   1                11                2        0
# 1  26                  12                11                2        0
# 2  24                  11                11                1        0
# 3  31                  24                11                4        0
# 4  18                  11                11                4        0
#
#    Transportation expense  Distance from Residence to Work  Service time  Age  \
# 0                      19                               19             3   15
# 1                      22                                9             5   18
# 2                       2                               13             5   17
# 3                       3                               20             0   12
# 4                      19                               19             3   15
#
#    Work load Average/day   ...  Disciplinary failure  Education  Son  \
# ...

# %%
#We can drop height and weight column as BMI is calculated with the help of two
df.drop(['Height','Weight'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 0  18                   1                11                2        0
# 1  26                  12                11                2        0
# 2  24                  11                11                1        0
# 3  31                  24                11                4        0
# 4  18                  11                11                4        0
#
#    Transportation expense  Distance from Residence to Work  Service time  Age  \
# 0                      19                               19             3   15
# 1                      22                                9             5   18
# 2                       2                               13             5   17
# 3                       3                               20             0   12
# 4                      19                               19             3   15
#
# ...

# %%
df.isnull().sum()
# Out:
# ID                                 0
# Reason for absence                 0
# Month of absence                   0
# Day of the week                    0
# Seasons                            0
# Transportation expense             0
# Distance from Residence to Work    0
# Service time                       0
# Age                                0
# Work load Average/day              0
# Hit target                         0
# Disciplinary failure               0
# Education                          0
# Son                                0
# Social drinker                     0
# Social smoker                      0
# Pet                                0
# Body mass index                    0
# Absenteeism time in hours          0
# dtype: int64

# %%
y=df['Absenteeism time in hours'].values

# %%
#independent varaibles
x= df.iloc[:,df.columns!='Absenteeism time in hours'].values

# %%
from sklearn.preprocessing import OrdinalEncoder
# Encoding
enc = OrdinalEncoder()
x= enc.fit_transform(x)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x =sc.fit_transform(x)

# %%
x
# Out:
# array([[ 0.23442699, -1.86081101,  1.56125858, ..., -0.28056586,
#          0.42393855,  2.38051233],
#        [ 1.14565992,  0.34367183,  1.56125858, ..., -0.28056586,
#         -0.65783568, -1.02679739],
#        [ 0.91785169,  0.1432643 ,  1.56125858, ..., -0.28056586,
#         -0.65783568, -1.02679739],
#        ...,
#        [ 0.80394757,  0.34367183, -1.39885249, ..., -0.28056586,
#         -0.65783568,  0.5458071 ],
#        [ 0.00661875,  0.34367183, -1.39885249, ..., -0.28056586,
#          1.50571279,  1.33210934],
#        [ 1.0317558 ,  0.34367183, -1.39885249, ..., -0.28056586,
#          0.42393855, -0.24049515]])

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state=9 )

# %%
print ('Train set:', x_train.shape,  y_train.shape)
print ('Test set:', x_test.shape,  y_test.shape)
# Out:
# Train set: (518, 18) (518,)
# Test set: (222, 18) (222,)

# %%
KNN=KNeighborsClassifier(n_neighbors=6)
SV=SVC()
LR=LogisticRegression()
DT=DecisionTreeClassifier(random_state=6)
GNB=GaussianNB()
RF=RandomForestClassifier()

# %%
models=[]
models.append(('KNeighborsClassifier',KNN))
models.append(('SVC',SV))
models.append(('LogisticRegression',LR))
models.append(('GaussianNB',GNB))
models.append(('RandomForestClassifier',RF))
models.append(('DecisionTreeClassifier',DT))

# %%
from sklearn.metrics import classification_report,accuracy_score,confusion_matrix,roc_curve,auc
from sklearn.metrics import roc_auc_score
from sklearn.multiclass import OneVsOneClassifier
from sklearn.datasets import make_classification
from sklearn.model_selection import cross_val_score

# %%
df.shape
# Out:
# (740, 19)

# %%
pd.set_option('display.max_columns',100)

# %%
pd.set_option('display.max_rows',1000)

# %%
Model=[]
score=[]
cvs=[]
rocscore=[]
for name, model in models:
    print('*********************',name,'***********************')
    print('\n')
    Model.append(name)
    model.fit(x_train, y_train)
    print(model)
    pre=model.predict(x_test)
    print('\n')
    AS=accuracy_score(y_test,pre)
    print('Accuracy_score=' ,AS)
    score.append(AS*100)
    print('\n')
    sc= cross_val_score(model,x, y, cv=10, scoring='accuracy').mean()
    print('Cross_Val_Score =',sc)
    cvs.append(sc*100)
    print('\n')
    print('classification_report\n',classification_report(y_test,pre))
    print('\n')
    cm=confusion_matrix(y_test,pre)
    print(cm)
    print('\n')
    plt.figure(figsize=(10,40))
    plt.subplot(911)
    plt.title(name)
    print(sns.heatmap(cm,annot=True))
    print('\n\n')
# Out:
# ********************* KNeighborsClassifier ***********************
#
#
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=6, p=2,
#                      weights='uniform')
#
#
# Accuracy_score= 0.46846846846846846
#
#
# Cross_Val_Score = 0.45
#
#
# classification_report
#                precision    recall  f1-score   support
#
#            0       0.55      0.77      0.64        86
#            1       0.25      0.17      0.20        30
#            2       0.43      0.41      0.42        49
#            3       0.29      0.21      0.24        19
#            4       0.43      0.25      0.32        36
#            5       0.00      0.00      0.00         2
#
#     accuracy                           0.47       222
#    macro avg       0.32      0.30      0.30       222
# weighted avg       0.44      0.47      0.44       222
#
#
#
# [[66  6  8  4  2  0]
#  [12  5  9  1  3  0]
# ...

# %%
result=pd.DataFrame({'Model':Model,'Accuracy_score':score, 'Cross_val_score':cvs})
result
# Out:
#                     Model  Accuracy_score  Cross_val_score
# 0    KNeighborsClassifier       46.846847        45.000000
# 1                     SVC       50.450450        45.135135
# 2      LogisticRegression       45.045045        39.864865
# 3              GaussianNB       15.765766        13.918919
# 4  RandomForestClassifier       54.954955        52.162162
# 5  DecisionTreeClassifier       48.648649        46.081081

# %% [markdown]
# I choose RandomForestClassifier for predicting Absenteeism in hours because it performed very well on my dataset

# %%
from sklearn.externals import joblib
#save the model for Tmax
joblib.dump(RF, 'Project16.obj')
# Out:
# ['Project16.obj']

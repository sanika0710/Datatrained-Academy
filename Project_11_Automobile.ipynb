# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %%
df=pd.read_csv('Auto_insurance_claim.csv')

# %%
df.head()
# Out:
#   Customer Country State Code     State  Claim Amount Response  Coverage  \
# 0  BU79786      US         KS    Kansas    276.351928       No     Basic
# 1  QZ44356      US         NE  Nebraska    697.953590       No  Extended
# 2  AI49188      US         OK  Oklahoma   1288.743165       No   Premium
# 3  WW63253      US         MO  Missouri    764.586183       No     Basic
# 4  HB64268      US         KS    Kansas    281.369258       No     Basic
#
#   Education Effective To Date EmploymentStatus  ...  \
# 0  Bachelor           2/24/11         Employed  ...
# 1  Bachelor           1/31/11       Unemployed  ...
# 2  Bachelor           2/19/11         Employed  ...
# 3  Bachelor           1/20/11       Unemployed  ...
# 4  Bachelor            2/3/11         Employed  ...
#
#   Months Since Policy Inception  Number of Open Complaints Number of Policies  \
# 0                             5                          0                  1
# ...

# %%
df.shape
# Out:
# (9134, 26)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9134 entries, 0 to 9133
# Data columns (total 26 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Customer                       9134 non-null   object
#  1   Country                        9134 non-null   object
#  2   State Code                     9134 non-null   object
#  3   State                          9134 non-null   object
#  4   Claim Amount                   9134 non-null   float64
#  5   Response                       9134 non-null   object
#  6   Coverage                       9134 non-null   object
#  7   Education                      9134 non-null   object
#  8   Effective To Date              9134 non-null   object
#  9   EmploymentStatus               9134 non-null   object
#  10  Gender                         9134 non-null   object
#  11  Income                         9134 non-null   int64
# ...

# %%
df.nunique()
# Out:
# Customer                         9134
# Country                             1
# State Code                          5
# State                               5
# Claim Amount                     8041
# Response                            2
# Coverage                            3
# Education                           5
# Effective To Date                  59
# EmploymentStatus                    5
# Gender                              2
# Income                           5694
# Location Code                       3
# Marital Status                      3
# Monthly Premium Auto              202
# Months Since Last Claim            36
# Months Since Policy Inception     100
# Number of Open Complaints           6
# Number of Policies                  9
# Policy Type                         3
# Policy                              9
# Claim Reason                        4
# Sales Channel                       4
# Total Claim Amount               5106
# Vehicle Class                       6
# ...

# %%
df.columns
# Out:
# Index(['Customer', 'Country', 'State Code', 'State', 'Claim Amount',
#        'Response', 'Coverage', 'Education', 'Effective To Date',
#        'EmploymentStatus', 'Gender', 'Income', 'Location Code',
#        'Marital Status', 'Monthly Premium Auto', 'Months Since Last Claim',
#        'Months Since Policy Inception', 'Number of Open Complaints',
#        'Number of Policies', 'Policy Type', 'Policy', 'Claim Reason',
#        'Sales Channel', 'Total Claim Amount', 'Vehicle Class', 'Vehicle Size'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Customer                         0
# Country                          0
# State Code                       0
# State                            0
# Claim Amount                     0
# Response                         0
# Coverage                         0
# Education                        0
# Effective To Date                0
# EmploymentStatus                 0
# Gender                           0
# Income                           0
# Location Code                    0
# Marital Status                   0
# Monthly Premium Auto             0
# Months Since Last Claim          0
# Months Since Policy Inception    0
# Number of Open Complaints        0
# Number of Policies               0
# Policy Type                      0
# Policy                           0
# Claim Reason                     0
# Sales Channel                    0
# Total Claim Amount               0
# Vehicle Class                    0
# Vehicle Size                     0
# dtype: int64

# %% [markdown]
# No null values in given dataset

# %% [raw]
# Univariate Analysis

# %%
plt.subplot(231)
df['Response'].value_counts(normalize=True).plot.bar(figsize=(20,10), title='Response')

plt.subplot(232)
df['Education'].value_counts(normalize=True).plot.bar(title= 'Education')


plt.subplot(234)
df['EmploymentStatus'].value_counts(normalize=True).plot.bar(title= 'EmploymentStatus')

plt.subplot(235)
df['Gender'].value_counts(normalize=True).plot.bar(title= 'Gender')

plt.show()

# %%
df['Monthly Premium Auto'].value_counts(normalize=True).plot.hist(figsize=(20,10),title= 'Monthly Premium Auto')

plt.show()

# %%
plt.subplot(231)
df['Months Since Last Claim'].value_counts(normalize=True).plot.bar(figsize=(30,10), title='Months Since Last Claim ')

plt.subplot(234)
df['Number of Open Complaints'].value_counts(normalize=True).plot.bar(title= 'Number of Open Complaints')

plt.subplot(235)
df['Number of Policies'].value_counts(normalize=True).plot.bar(title= 'Number of Policies')

plt.show()

# %%
df['Months Since Policy Inception'].value_counts(normalize=True).plot.bar(figsize=(20,10),title='Months Since Policy Inception')

# %%
plt.subplot(231)
df['Policy Type'].value_counts(normalize=True).plot.bar(figsize=(20,10), title='Policy Type')

plt.subplot(232)
df['Policy'].value_counts(normalize=True).plot.bar(title= 'Policy')


plt.subplot(234)
df['Claim Reason'].value_counts(normalize=True).plot.bar(title= 'Claim Reason')

plt.subplot(235)
df['Sales Channel'].value_counts(normalize=True).plot.bar(title= 'Sales Channel')

plt.show()

# %%
plt.subplot(232)
df['Vehicle Class'].value_counts(normalize=True).plot.bar(figsize=(10,10),title= 'Vehicle Class')


plt.subplot(233)
df['Vehicle Size'].value_counts(normalize=True).plot.bar(figsize=(10,10),title= 'Vehicle Size')

# %%
sns.distplot(df['Total Claim Amount'])

# %%
df.describe()
# Out:
#        Claim Amount        Income  Monthly Premium Auto  \
# count   9134.000000   9134.000000           9134.000000
# mean     800.494047  37657.380009             93.219291
# std      687.096761  30379.904734             34.407967
# min      189.800768      0.000000             61.000000
# 25%      399.425179      0.000000             68.000000
# 50%      578.018220  33889.500000             83.000000
# 75%      896.216704  62320.000000            109.000000
# max     8332.538119  99981.000000            298.000000
#
#        Months Since Last Claim  Months Since Policy Inception  \
# count              9134.000000                    9134.000000
# mean                 15.097000                      48.064594
# std                  10.073257                      27.905991
# min                   0.000000                       0.000000
# 25%                   6.000000                      24.000000
# 50%                  14.000000                      48.000000
# ...

# %%
df.skew()
# Out:
# Claim Amount                     3.032280
# Income                           0.286887
# Monthly Premium Auto             2.123546
# Months Since Last Claim          0.278586
# Months Since Policy Inception    0.040165
# Number of Open Complaints        2.783263
# Number of Policies               1.253333
# Total Claim Amount               1.714966
# dtype: float64

# %%
df.plot(kind='box',subplots=True,layout=(2,4))
# Out:
# Claim Amount                        AxesSubplot(0.125,0.536818;0.168478x0.343182)
# Income                           AxesSubplot(0.327174,0.536818;0.168478x0.343182)
# Monthly Premium Auto             AxesSubplot(0.529348,0.536818;0.168478x0.343182)
# Months Since Last Claim          AxesSubplot(0.731522,0.536818;0.168478x0.343182)
# Months Since Policy Inception          AxesSubplot(0.125,0.125;0.168478x0.343182)
# Number of Open Complaints           AxesSubplot(0.327174,0.125;0.168478x0.343182)
# Number of Policies                  AxesSubplot(0.529348,0.125;0.168478x0.343182)
# Total Claim Amount                  AxesSubplot(0.731522,0.125;0.168478x0.343182)
# dtype: object

# %%
df['Claim Amount'].plot.box()

# %%
df['Monthly Premium Auto'].plot.box()

# %%
df['Number of Open Complaints'].plot.box()

# %%
df['Total Claim Amount'].plot.box()

# %% [markdown]
# From Univariate Analysis We concluded that, there is certain skewness and outliers are present, Which we will remove further

# %% [raw]
# Bivariate Analysis

# %%
sns.barplot(x = 'Response', y = 'Claim Amount', data=df)

# %%
sns.barplot(x = 'Coverage', y = 'Claim Amount', data=df)

# %%
plt.figure(figsize=(24,15))
sns.barplot(x='Income',y='Claim Amount',data=df)
plt.xticks(rotation=90)
plt.xlabel('Income')
plt.ylabel('Claim Amount')
# Out:
# Text(0, 0.5, 'Claim Amount')

# %%
sns.barplot(x = 'Marital Status', y = 'Claim Amount', data=df)

# %%
plt.figure(figsize=(30,15))
sns.barplot(x = 'Monthly Premium Auto', y = 'Claim Amount', data=df)

# %%
plt.figure(figsize=(24,15))
sns.barplot(x = 'Months Since Last Claim', y = 'Claim Amount', data=df)

# %%
plt.figure(figsize=(24,15))
sns.barplot(x = 'Months Since Policy Inception', y = 'Claim Amount', data=df)

# %%
sns.barplot(x = 'Number of Policies', y = 'Claim Amount', data=df)

# %%
sns.barplot(x = 'Vehicle Size', y = 'Claim Amount', data=df)

# %%
plt.figure(figsize=(24,15))
sns.barplot(x = 'Total Claim Amount', y = 'Claim Amount', data=df)

# %%
plt.figure(figsize=(24,15))
sns.barplot(x = 'Income', y = 'Claim Amount', data=df)

# %%
sns.barplot(x = 'Location Code', y = 'Claim Amount', data=df)

# %%
sns.pairplot(df)

# %%
df.columns
# Out:
# Index(['Customer', 'Country', 'State Code', 'State', 'Claim Amount',
#        'Response', 'Coverage', 'Education', 'Effective To Date',
#        'EmploymentStatus', 'Gender', 'Income', 'Location Code',
#        'Marital Status', 'Monthly Premium Auto', 'Months Since Last Claim',
#        'Months Since Policy Inception', 'Number of Open Complaints',
#        'Number of Policies', 'Policy Type', 'Policy', 'Claim Reason',
#        'Sales Channel', 'Total Claim Amount', 'Vehicle Class', 'Vehicle Size'],
#       dtype='object')

# %%
df.drop(['Marital Status','State','Policy','Education','Gender','Location Code','Country'],axis=1)
# Out:
#      Customer State Code  Claim Amount Response  Coverage Effective To Date  \
# 0     BU79786         KS    276.351928       No     Basic           2/24/11
# 1     QZ44356         NE    697.953590       No  Extended           1/31/11
# 2     AI49188         OK   1288.743165       No   Premium           2/19/11
# 3     WW63253         MO    764.586183       No     Basic           1/20/11
# 4     HB64268         KS    281.369258       No     Basic            2/3/11
# ...       ...        ...           ...      ...       ...               ...
# 9129  LA72316         MO   2340.598798       No     Basic           2/10/11
# 9130  PK87824         MO    309.651122      Yes  Extended           2/12/11
# 9131  TD14365         MO    816.389043       No  Extended            2/6/11
# 9132  UP19263         MO    752.444244       No  Extended            2/3/11
# 9133  Y167826         MO    261.183687       No  Extended           2/14/11
#
# ...

# %%
df['Month'] = pd.DatetimeIndex(df['Effective To Date']).month
df.head()
# Out:
#   Customer Country State Code     State  Claim Amount Response  Coverage  \
# 0  BU79786      US         KS    Kansas    276.351928       No     Basic
# 1  QZ44356      US         NE  Nebraska    697.953590       No  Extended
# 2  AI49188      US         OK  Oklahoma   1288.743165       No   Premium
# 3  WW63253      US         MO  Missouri    764.586183       No     Basic
# 4  HB64268      US         KS    Kansas    281.369258       No     Basic
#
#   Education Effective To Date EmploymentStatus  ... Number of Open Complaints  \
# 0  Bachelor           2/24/11         Employed  ...                         0
# 1  Bachelor           1/31/11       Unemployed  ...                         0
# 2  Bachelor           2/19/11         Employed  ...                         0
# 3  Bachelor           1/20/11       Unemployed  ...                         0
# 4  Bachelor            2/3/11         Employed  ...                         0
#
# ...

# %%
df['Date'] = pd.DatetimeIndex(df['Effective To Date']).day
df.head()
# Out:
#   Customer Country State Code     State  Claim Amount Response  Coverage  \
# 0  BU79786      US         KS    Kansas    276.351928       No     Basic
# 1  QZ44356      US         NE  Nebraska    697.953590       No  Extended
# 2  AI49188      US         OK  Oklahoma   1288.743165       No   Premium
# 3  WW63253      US         MO  Missouri    764.586183       No     Basic
# 4  HB64268      US         KS    Kansas    281.369258       No     Basic
#
#   Education Effective To Date EmploymentStatus  ... Number of Policies  \
# 0  Bachelor           2/24/11         Employed  ...                  1
# 1  Bachelor           1/31/11       Unemployed  ...                  8
# 2  Bachelor           2/19/11         Employed  ...                  2
# 3  Bachelor           1/20/11       Unemployed  ...                  7
# 4  Bachelor            2/3/11         Employed  ...                  1
#
#       Policy Type        Policy  Claim Reason  Sales Channel  \
# ...

# %%
df['Effective To Date'].value_counts()
# Out:
# 1/10/11    195
# 1/27/11    194
# 2/14/11    186
# 1/26/11    181
# 1/17/11    180
# 1/19/11    179
# 1/31/11    178
# 1/3/11     178
# 1/20/11    173
# 1/28/11    169
# 2/26/11    169
# 2/19/11    168
# 1/5/11     167
# 2/27/11    167
# 1/11/11    166
# 2/4/11     164
# 2/28/11    161
# 2/10/11    161
# 1/2/11     160
# 1/29/11    160
# 1/21/11    160
# 2/22/11    158
# 2/3/11     158
# 2/5/11     158
# 2/7/11     157
# 2/12/11    156
# 1/23/11    155
# 1/18/11    154
# 2/1/11     154
# 1/15/11    153
# 1/14/11    152
# 2/11/11    151
# 1/25/11    151
# 1/7/11     151
# 2/18/11    149
# 2/25/11    149
# 1/8/11     149
# 2/2/11     149
# 1/1/11     148
# 2/21/11    148
# 1/24/11    147
# 1/9/11     146
# 1/30/11    145
# 1/13/11    145
# 2/6/11     144
# 2/23/11    143
# 1/6/11     143
# 1/16/11    142
# 2/24/11    139
# 2/13/11    139
# 2/16/11    139
# 2/9/11     137
# 2/17/11    136
# 1/22/11    136
# 2/8/11     134
# 2/20/11    132
# 2/15/11    130
# 1/12/11    126
# ...

# %%
df['Year'] = pd.DatetimeIndex(df['Effective To Date']).year
df.head()
# Out:
#   Customer Country State Code     State  Claim Amount Response  Coverage  \
# 0  BU79786      US         KS    Kansas    276.351928       No     Basic
# 1  QZ44356      US         NE  Nebraska    697.953590       No  Extended
# 2  AI49188      US         OK  Oklahoma   1288.743165       No   Premium
# 3  WW63253      US         MO  Missouri    764.586183       No     Basic
# 4  HB64268      US         KS    Kansas    281.369258       No     Basic
#
#   Education Effective To Date EmploymentStatus  ...     Policy Type  \
# 0  Bachelor           2/24/11         Employed  ...  Corporate Auto
# 1  Bachelor           1/31/11       Unemployed  ...   Personal Auto
# 2  Bachelor           2/19/11         Employed  ...   Personal Auto
# 3  Bachelor           1/20/11       Unemployed  ...  Corporate Auto
# 4  Bachelor            2/3/11         Employed  ...   Personal Auto
#
#          Policy  Claim Reason Sales Channel  Total Claim Amount  \
# ...

# %%
df1=df.drop(['Effective To Date','Marital Status','State','Policy','Education','Gender','Location Code','Country'],axis=1)
df1
# Out:
#      Customer State Code  Claim Amount Response  Coverage EmploymentStatus  \
# 0     BU79786         KS      5.625287       No     Basic         Employed
# 1     QZ44356         NE      6.549584       No  Extended       Unemployed
# 2     AI49188         OK      7.162198       No   Premium         Employed
# 3     WW63253         MO      6.640642       No     Basic       Unemployed
# 4     HB64268         KS      5.643216       No     Basic         Employed
# ...       ...        ...           ...      ...       ...              ...
# 9129  LA72316         MO      7.758589       No     Basic         Employed
# 9130  PK87824         MO      5.738670      Yes  Extended         Employed
# 9131  TD14365         MO      6.706115       No  Extended       Unemployed
# 9132  UP19263         MO      6.624655       No  Extended         Employed
# 9133  Y167826         MO      5.569045       No  Extended       Unemployed
#
#       Income  Monthly Premium Auto  Months Since Last Claim  \
# ...

# %%
df_cor=df1.corr()
sns.heatmap(df_cor)

# %%
df1.skew()
# Out:
# Claim Amount                     0.578248
# Income                           0.286887
# Monthly Premium Auto             1.013663
# Months Since Last Claim          0.278586
# Months Since Policy Inception    0.040165
# Number of Open Complaints        1.999011
# Number of Policies               0.657633
# Total Claim Amount              -1.741369
# Month                            0.145359
# Date                             0.006796
# Year                             0.000000
# dtype: float64

# %%
skew=['Claim Amount','Monthly Premium Auto','Number of Open Complaints','Number of Policies','Total Claim Amount']
for col in skew :
    if df.skew().loc[col]>0.55:
        df[col] = np.log1p(df[col])

# %%
df1.skew()
# Out:
# Claim Amount                     0.578248
# Income                           0.286887
# Monthly Premium Auto             1.013663
# Months Since Last Claim          0.278586
# Months Since Policy Inception    0.040165
# Number of Open Complaints        1.999011
# Number of Policies               0.657633
# Total Claim Amount              -1.741369
# Month                            0.145359
# Date                             0.006796
# Year                             0.000000
# dtype: float64

# %%
y=df1['Claim Amount'].values

# %%
#independent varaibles
x= df1.iloc[:,df1.columns!='Claim Amount'].values

# %%
from sklearn.preprocessing import OrdinalEncoder
# Encoding
enc = OrdinalEncoder()
x= enc.fit_transform(x)

# %%
df1.dtypes
# Out:
# Customer                           int32
# State Code                         int32
# Claim Amount                     float64
# Response                           int32
# Coverage                           int32
# EmploymentStatus                   int32
# Income                             int64
# Monthly Premium Auto             float64
# Months Since Last Claim            int64
# Months Since Policy Inception      int64
# Number of Open Complaints        float64
# Number of Policies               float64
# Policy Type                        int32
# Claim Reason                       int32
# Sales Channel                      int32
# Total Claim Amount               float64
# Vehicle Class                      int32
# Vehicle Size                       int32
# Month                              int64
# Date                               int64
# Year                               int64
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder
column=['Customer','State Code','Response','Coverage','EmploymentStatus','Policy Type','Claim Reason',
        'Sales Channel','Vehicle Size','Vehicle Class']
le=LabelEncoder()
for i in column:
    df1[i] = le.fit_transform(df1[i].astype(str))

print(df1.dtypes)
# Out:
# Customer                           int32
# State Code                         int32
# Claim Amount                     float64
# Response                           int32
# Coverage                           int32
# EmploymentStatus                   int32
# Income                             int64
# Monthly Premium Auto             float64
# Months Since Last Claim            int64
# Months Since Policy Inception      int64
# Number of Open Complaints        float64
# Number of Policies               float64
# Policy Type                        int32
# Claim Reason                       int32
# Sales Channel                      int32
# Total Claim Amount               float64
# Vehicle Class                      int32
# Vehicle Size                       int32
# Month                              int64
# Date                               int64
# Year                               int64
# dtype: object

# %%
df1.head()
# Out:
#    Customer  State Code  Claim Amount  Response  Coverage  EmploymentStatus  \
# 0      4520           1      5.625287         0         0                 1
# 1      4443           3      6.549584         0         1                 4
# 2      8880           4      7.162198         0         2                 1
# 3      7284           2      6.640642         0         0                 4
# 4      7002           1      5.643216         0         0                 1
#
#    Income  Monthly Premium Auto  Months Since Last Claim  \
# 0   56274              4.248495                       32
# 1       0              4.553877                       13
# 2   48767              4.691348                       18
# 3       0              4.672829                       18
# 4   43836              4.304065                       12
#
#    Months Since Policy Inception  ...  Number of Policies  Policy Type  \
# 0                              5  ...            0.693147            0
# ...

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x =sc.fit_transform(x)

# %%
x
# Out:
# array([[ 0.18943713, -0.55068994, -0.40882171, ...,  1.07530438,
#          0.98677607,  0.        ],
#        [ 0.16364789,  0.97332215, -0.40882171, ..., -0.92996924,
#          1.79571635,  0.        ],
#        [ 1.67800719,  1.73532819, -0.40882171, ...,  1.07530438,
#          0.40896158,  0.        ],
#        ...,
#        [ 0.51142337,  0.21131611, -0.40882171, ...,  1.07530438,
#         -1.09335608,  0.        ],
#        [ 0.75793816,  0.21131611, -0.40882171, ...,  1.07530438,
#         -1.44004477,  0.        ],
#        [ 1.32909395,  0.21131611, -0.40882171, ...,  1.07530438,
#         -0.1688529 ,  0.        ]])

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error
from sklearn import linear_model
def maxr2_score(regr,x,y):
    max_r_score=0
    for r_state in range(42,100):
        x_train, x_test, y_train, y_test = train_test_split(x,y,random_state=r_state,test_size=0.20)
        regr.fit(x_train,y_train)
        y_pred=regr.predict(x_test)
        r2_scr=r2_score(y_test,y_pred)
        print('r2_score corresponding to random state:',r_state,'is',r2_scr)
        if r2_scr>max_r_score:
            max_r_score=r2_scr
            final_r_state=r_state

    print('max r2 score corresponding to',final_r_state,'is:',max_r_score)
    return final_r_state

# %%
#lets use Linear Regression and check max_r2_score
from sklearn.linear_model import LinearRegression
lreg=LinearRegression()
r_state=maxr2_score(lreg,x,y)
# Out:
# r2_score corresponding to random state: 42 is 0.2488894791728572
# r2_score corresponding to random state: 43 is 0.24641930375754173
# r2_score corresponding to random state: 44 is 0.22943680980426906
# r2_score corresponding to random state: 45 is 0.23956141249044915
# r2_score corresponding to random state: 46 is 0.2595756354636334
# r2_score corresponding to random state: 47 is 0.2683040173095831
# r2_score corresponding to random state: 48 is 0.2662512809918337
# r2_score corresponding to random state: 49 is 0.24582299760226622
# r2_score corresponding to random state: 50 is 0.2675037546002824
# r2_score corresponding to random state: 51 is 0.19856269127533277
# r2_score corresponding to random state: 52 is 0.253090461660916
# r2_score corresponding to random state: 53 is 0.23918794278679523
# r2_score corresponding to random state: 54 is 0.2273865980661206
# r2_score corresponding to random state: 55 is 0.26634090601629334
# ...

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsRegressor
neighbors={'n_neighbors':range(1,30)}
knr=KNeighborsRegressor()
gknr=GridSearchCV(knr,neighbors,cv=10)
gknr.fit(x,y)
gknr.best_params_
# Out:
# {'n_neighbors': 18}

# %%
#lets use KNN regression and check max r2 score
knr=KNeighborsRegressor(n_neighbors=18)
r_state=maxr2_score(knr,x,y)
# Out:
# r2_score corresponding to random state: 42 is 0.22197729859813065
# r2_score corresponding to random state: 43 is 0.23046751512999963
# r2_score corresponding to random state: 44 is 0.23071208226333983
# r2_score corresponding to random state: 45 is 0.23907829530813085
# r2_score corresponding to random state: 46 is 0.23594344095741648
# r2_score corresponding to random state: 47 is 0.259205465134555
# r2_score corresponding to random state: 48 is 0.23747379454235362
# r2_score corresponding to random state: 49 is 0.2623800057218175
# r2_score corresponding to random state: 50 is 0.23937288825796055
# r2_score corresponding to random state: 51 is 0.196168744548045
# r2_score corresponding to random state: 52 is 0.24500876367460211
# r2_score corresponding to random state: 53 is 0.22964170707606357
# r2_score corresponding to random state: 54 is 0.2295879359701215
# r2_score corresponding to random state: 55 is 0.25397805222274605
# ...

# %%
from sklearn.model_selection import cross_val_score
print('Mean r2 score for Linear Regression:',cross_val_score(lreg,x,y,cv=5,scoring='r2').mean())
print('standard deviation in r2 score for Linear Regression: ',cross_val_score(lreg,x,y,cv=5,scoring='r2').std())
print()
print('Mean r2 score for KNN Regression:',cross_val_score(knr,x,y,cv=5,scoring='r2').mean())
print('standard deviation in r2 score for KNeighborsRegressor: ',cross_val_score(knr,x,y,cv=5,scoring='r2').std())
print()
# Out:
# Mean r2 score for Linear Regression: 0.2442770110975488
# standard deviation in r2 score for Linear Regression:  0.015390802098895325
#
# Mean r2 score for KNN Regression: 0.23930367471919745
# standard deviation in r2 score for KNeighborsRegressor:  0.020217382464310905

# %%
#lets check lasso regression & find alpha
from sklearn.linear_model import Lasso
lsreg=Lasso()
parameters={'alpha':[0.001,0.01,0.1,1]}
clf=GridSearchCV(lsreg,parameters,cv=10)
clf.fit(x,y)
clf.best_params_
# Out:
# {'alpha': 0.001}

# %%
#lets check max_r2_score with alpha=0.001
lsreg=Lasso(alpha=0.001)
r_state=maxr2_score(lsreg,x,y)
# Out:
# r2_score corresponding to random state: 42 is 0.24868316563897674
# r2_score corresponding to random state: 43 is 0.24658444292415782
# r2_score corresponding to random state: 44 is 0.23004849406782468
# r2_score corresponding to random state: 45 is 0.23928983144890614
# r2_score corresponding to random state: 46 is 0.25948838095833715
# r2_score corresponding to random state: 47 is 0.26821118835871993
# r2_score corresponding to random state: 48 is 0.26588494409390373
# r2_score corresponding to random state: 49 is 0.24563821972615407
# r2_score corresponding to random state: 50 is 0.26732695497958736
# r2_score corresponding to random state: 51 is 0.19900122503427553
# r2_score corresponding to random state: 52 is 0.2527976813214662
# r2_score corresponding to random state: 53 is 0.23932668129966084
# r2_score corresponding to random state: 54 is 0.22758388616325032
# r2_score corresponding to random state: 55 is 0.2659113595376337
# ...

# %%
print('Mean r2 score for Lasso Regression:',cross_val_score(lsreg,x,y,cv=5,scoring='r2').mean())
print('standard deviation in r2 score for Lasso Regression: ',cross_val_score(lsreg,x,y,cv=5,scoring='r2').std())
print()
# Out:
# Mean r2 score for Lasso Regression: 0.24437836953272965
# standard deviation in r2 score for Lasso Regression:  0.015254359369188002

# %%
#Now we will try to boost 
from sklearn.ensemble import GradientBoostingRegressor
import warnings
warnings.filterwarnings('ignore')
gbr=GradientBoostingRegressor()
parameters={'learning_rate':[0.001,0.01,0.1,1],'n_estimators':[10,100,500,1000]}
clf=GridSearchCV(gbr,parameters,cv=5)
clf.fit(x,y)
clf.best_params_
# Out:
# {'learning_rate': 0.1, 'n_estimators': 500}

# %%
gbr=GradientBoostingRegressor(learning_rate=0.1 ,n_estimators=500 )
print('Mean r2 score for GradientBoostingRegressor:',cross_val_score(gbr,x,y,cv=5,scoring='r2').mean())
print('standard deviation in r2 score for GradientBoostingRegressor: ',cross_val_score(gbr,x,y,cv=5,scoring='r2').std())
print()
# Out:
# Mean r2 score for GradientBoostingRegressor: 0.903854458545146
# standard deviation in r2 score for GradientBoostingRegressor:  0.0036363253025943534

# %%
from sklearn.ensemble import AdaBoostRegressor
from sklearn.tree import DecisionTreeRegressor
import warnings
warnings.filterwarnings('ignore')
ada_reg=AdaBoostRegressor()
parameters={'learning_rate':[0.001,0.01,0.1,1],'n_estimators':[10,100,500,1000],
            'base_estimator':[lreg,lsreg,DecisionTreeRegressor()]}
clf=GridSearchCV(ada_reg,parameters,cv=5)
clf.fit(x,y)
clf.best_params_
# Out:
# {'base_estimator': DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=None,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best'),
#  'learning_rate': 1,
#  'n_estimators': 1000}

# %%
ada_reg=AdaBoostRegressor(learning_rate=1 ,n_estimators=1000 )
print('Mean r2 score for AdaBoostRegressor:',cross_val_score(ada_reg,x,y,cv=5,scoring='r2').mean())
print('standard deviation in r2 score for AdaBoostRegressor: ',cross_val_score(ada_reg,x,y,cv=5,scoring='r2').std())
print()
# Out:
# Mean r2 score for AdaBoostRegressor: 0.8343235895525419
# standard deviation in r2 score for AdaBoostRegressor:  0.020942337944090447

# %%
r_state=maxr2_score(ada_reg,x,y)
# Out:
# r2_score corresponding to random state: 42 is 0.8270883550457313
# r2_score corresponding to random state: 43 is 0.8690692331053709
# r2_score corresponding to random state: 44 is 0.835425264255275
# r2_score corresponding to random state: 45 is 0.8569938272651918
# r2_score corresponding to random state: 46 is 0.8616499922904306
# r2_score corresponding to random state: 47 is 0.8580191371628563
# r2_score corresponding to random state: 48 is 0.8573673192584456
# r2_score corresponding to random state: 49 is 0.8424199430429206
# r2_score corresponding to random state: 50 is 0.8317634985813123
# r2_score corresponding to random state: 51 is 0.836766782348032
# r2_score corresponding to random state: 52 is 0.8179076623631083
# r2_score corresponding to random state: 53 is 0.8253043691706001
# r2_score corresponding to random state: 54 is 0.8465638798350164
# r2_score corresponding to random state: 55 is 0.8479970410959118
# ...

# %%
r_state=maxr2_score(gbr,x,y)
# Out:
# r2_score corresponding to random state: 42 is 0.9053233620842068
# r2_score corresponding to random state: 43 is 0.9061704876570102
# r2_score corresponding to random state: 44 is 0.9003331648938692
# r2_score corresponding to random state: 45 is 0.9070192032987936
# r2_score corresponding to random state: 46 is 0.9004778012694044
# r2_score corresponding to random state: 47 is 0.9098051398698139
# r2_score corresponding to random state: 48 is 0.9084295109958873
# r2_score corresponding to random state: 49 is 0.903634591360848
# r2_score corresponding to random state: 50 is 0.9033611768297878
# r2_score corresponding to random state: 51 is 0.893468483069467
# r2_score corresponding to random state: 52 is 0.8974557797459943
# r2_score corresponding to random state: 53 is 0.895033714176948
# r2_score corresponding to random state: 54 is 0.8998263026365041
# r2_score corresponding to random state: 55 is 0.9117918505362261
# ...

# %%
#We tried all the models and till now the best is GradientBoostingRegressor
x_train,x_test,y_train,y_test = train_test_split(x,y,random_state =87 ,test_size = 0.20)
gbr=GradientBoostingRegressor()
gbr.fit(x_train, y_train)
y_pred=gbr.predict(x_test)

# %%
import numpy as np
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
print('RMSE:', np.sqrt(mean_squared_error(y_test, y_pred)))
print('r2 score is:',r2_score(y_test, y_pred))
# Out:
# RMSE: 0.18711428709157873
# r2 score is: 0.914606593964895

# %% [markdown]
# I choose GradientBoostingRegressor as my final model because it performed very well on dataset

# %%
from sklearn.externals import joblib
#save the model 
joblib.dump(gbr, 'Project11.obj')
# Out:
# ['Project11.obj']

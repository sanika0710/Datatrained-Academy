# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_excel(r'C:\Users\SANIKA\Documents\ElectionData.xlsx')

# %%
df.head()
# Out:
#    TimeElapsed                time         territoryName  totalMandates  \
# 0            0 2019-10-06 20:10:02  TerritÃ³rio Nacional              0
# 1            0 2019-10-06 20:10:02  TerritÃ³rio Nacional              0
# 2            0 2019-10-06 20:10:02  TerritÃ³rio Nacional              0
# 3            0 2019-10-06 20:10:02  TerritÃ³rio Nacional              0
# 4            0 2019-10-06 20:10:02  TerritÃ³rio Nacional              0
#
#    availableMandates  numParishes  numParishesApproved  blankVotes  \
# 0                226         3092                 1081        9652
# 1                226         3092                 1081        9652
# 2                226         3092                 1081        9652
# 3                226         3092                 1081        9652
# 4                226         3092                 1081        9652
#
#    blankVotesPercentage  nullVotes  ...  pre.votersPercentage  \
# 0                   2.5       8874  ...                 52.66
# ...

# %%
df.shape
# Out:
# (21643, 28)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21643 entries, 0 to 21642
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   TimeElapsed               21643 non-null  int64
#  1   time                      21643 non-null  datetime64[ns]
#  2   territoryName             21643 non-null  object
#  3   totalMandates             21643 non-null  int64
#  4   availableMandates         21643 non-null  int64
#  5   numParishes               21643 non-null  int64
#  6   numParishesApproved       21643 non-null  int64
#  7   blankVotes                21643 non-null  int64
#  8   blankVotesPercentage      21643 non-null  float64
#  9   nullVotes                 21643 non-null  int64
#  10  nullVotesPercentage       21643 non-null  float64
#  11  votersPercentage          21643 non-null  float64
#  12  subscribedVoters          21643 non-null  int64
# ...

# %%
df.nunique()
# Out:
# TimeElapsed                   54
# time                          54
# territoryName                 21
# totalMandates                 62
# availableMandates             69
# numParishes                   20
# numParishesApproved          219
# blankVotes                   329
# blankVotesPercentage         146
# nullVotes                    331
# nullVotesPercentage          107
# votersPercentage             282
# subscribedVoters             335
# totalVoters                  336
# pre.blankVotes               323
# pre.blankVotesPercentage     130
# pre.nullVotes                329
# pre.nullVotesPercentage       90
# pre.votersPercentage         278
# pre.subscribedVoters         331
# pre.totalVoters              331
# Party                         21
# Mandates                      67
# Percentage                  1363
# validVotesPercentage        1387
# Votes                       4029
# Hondt                         41
# FinalMandates                 17
# dtype: int64

# %%
df.isnull().sum()
# Out:
# TimeElapsed                 0
# time                        0
# territoryName               0
# totalMandates               0
# availableMandates           0
# numParishes                 0
# numParishesApproved         0
# blankVotes                  0
# blankVotesPercentage        0
# nullVotes                   0
# nullVotesPercentage         0
# votersPercentage            0
# subscribedVoters            0
# totalVoters                 0
# pre.blankVotes              0
# pre.blankVotesPercentage    0
# pre.nullVotes               0
# pre.nullVotesPercentage     0
# pre.votersPercentage        0
# pre.subscribedVoters        0
# pre.totalVoters             0
# Party                       0
# Mandates                    0
# Percentage                  0
# validVotesPercentage        0
# Votes                       0
# Hondt                       0
# FinalMandates               0
# dtype: int64

# %%
df.describe()
# Out:
#         TimeElapsed  totalMandates  availableMandates   numParishes  \
# count  21643.000000   21643.000000       21643.000000  21643.000000
# mean     133.146052      11.544795          11.499284    309.956013
# std       77.651193      31.314567          31.738783    659.055911
# min        0.000000       0.000000           0.000000     54.000000
# 25%       65.000000       1.000000           0.000000     75.000000
# 50%      135.000000       4.000000           3.000000    147.000000
# 75%      200.000000       9.000000           9.000000    242.000000
# max      265.000000     226.000000         226.000000   3092.000000
#
#        numParishesApproved     blankVotes  blankVotesPercentage     nullVotes  \
# count         21643.000000   21643.000000          21643.000000  21643.000000
# mean            261.090237    8875.066673              2.621629   6148.068752
# std             583.377428   21484.874088              0.795289  14735.469269
# ...

# %%
plt.figure(figsize=(15,10))
df_cor=df.corr()
sns.heatmap(df_cor,annot=True)

# %%
df.tail()
# Out:
#        TimeElapsed                time territoryName  totalMandates  \
# 21638          265 2019-10-07 00:35:01         Viseu              8
# 21639          265 2019-10-07 00:35:01         Viseu              8
# 21640          265 2019-10-07 00:35:01         Viseu              8
# 21641          265 2019-10-07 00:35:01         Viseu              8
# 21642          265 2019-10-07 00:35:01         Viseu              8
#
#        availableMandates  numParishes  numParishesApproved  blankVotes  \
# 21638                  0          277                  277        4995
# 21639                  0          277                  277        4995
# 21640                  0          277                  277        4995
# 21641                  0          277                  277        4995
# 21642                  0          277                  277        4995
#
#        blankVotesPercentage  nullVotes  ...  pre.votersPercentage  \
# ...

# %%
df['Day']=pd.to_datetime(df['time'],format='%Y-%d-%m').dt.day

# %%
df['Month']=pd.to_datetime(df['time'],format='%Y-%d-%m').dt.month

# %%
df['Year']=pd.to_datetime(df['time'],format='%Y-%d-%m').dt.year

# %%
df.head()
# Out:
#    TimeElapsed                time         territoryName  totalMandates  \
# 0            0 2019-10-06 20:10:02  TerritÃ³rio Nacional              0
# 1            0 2019-10-06 20:10:02  TerritÃ³rio Nacional              0
# 2            0 2019-10-06 20:10:02  TerritÃ³rio Nacional              0
# 3            0 2019-10-06 20:10:02  TerritÃ³rio Nacional              0
# 4            0 2019-10-06 20:10:02  TerritÃ³rio Nacional              0
#
#    availableMandates  numParishes  numParishesApproved  blankVotes  \
# 0                226         3092                 1081        9652
# 1                226         3092                 1081        9652
# 2                226         3092                 1081        9652
# 3                226         3092                 1081        9652
# 4                226         3092                 1081        9652
#
#    blankVotesPercentage  nullVotes  ...    Party  Mandates  Percentage  \
# ...

# %%
df['Hour']=pd.to_datetime(df['time'],format='%H-%M-%S').dt.hour

# %%
df['Minutes']=pd.to_datetime(df['time'],format='%H-%M-%S').dt.minute

# %%
df['Seconds']=pd.to_datetime(df['time'],format='%H-%M-%S').dt.second

# %%
df.head()
# Out:
#    TimeElapsed                time         territoryName  totalMandates  \
# 0            0 2019-10-06 20:10:02  TerritÃ³rio Nacional              0
# 1            0 2019-10-06 20:10:02  TerritÃ³rio Nacional              0
# 2            0 2019-10-06 20:10:02  TerritÃ³rio Nacional              0
# 3            0 2019-10-06 20:10:02  TerritÃ³rio Nacional              0
# 4            0 2019-10-06 20:10:02  TerritÃ³rio Nacional              0
#
#    availableMandates  numParishes  numParishesApproved  blankVotes  \
# 0                226         3092                 1081        9652
# 1                226         3092                 1081        9652
# 2                226         3092                 1081        9652
# 3                226         3092                 1081        9652
# 4                226         3092                 1081        9652
#
#    blankVotesPercentage  nullVotes  ...  validVotesPercentage   Votes  Hondt  \
# ...

# %%
df.dtypes
# Out:
# TimeElapsed                          int64
# time                        datetime64[ns]
# territoryName                       object
# totalMandates                        int64
# availableMandates                    int64
# numParishes                          int64
# numParishesApproved                  int64
# blankVotes                           int64
# blankVotesPercentage               float64
# nullVotes                            int64
# nullVotesPercentage                float64
# votersPercentage                   float64
# subscribedVoters                     int64
# totalVoters                          int64
# pre.blankVotes                       int64
# pre.blankVotesPercentage           float64
# pre.nullVotes                        int64
# pre.nullVotesPercentage            float64
# pre.votersPercentage               float64
# pre.subscribedVoters                 int64
# pre.totalVoters                      int64
# Party                               object
# ...

# %%
df.drop(['time'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    TimeElapsed         territoryName  totalMandates  availableMandates  \
# 0            0  TerritÃ³rio Nacional              0                226
# 1            0  TerritÃ³rio Nacional              0                226
# 2            0  TerritÃ³rio Nacional              0                226
# 3            0  TerritÃ³rio Nacional              0                226
# 4            0  TerritÃ³rio Nacional              0                226
#
#    numParishes  numParishesApproved  blankVotes  blankVotesPercentage  \
# 0         3092                 1081        9652                   2.5
# 1         3092                 1081        9652                   2.5
# 2         3092                 1081        9652                   2.5
# 3         3092                 1081        9652                   2.5
# 4         3092                 1081        9652                   2.5
#
#    nullVotes  nullVotesPercentage  ...  validVotesPercentage   Votes  Hondt  \
# ...

# %%
df.dtypes
# Out:
# TimeElapsed                   int64
# territoryName                object
# totalMandates                 int64
# availableMandates             int64
# numParishes                   int64
# numParishesApproved           int64
# blankVotes                    int64
# blankVotesPercentage        float64
# nullVotes                     int64
# nullVotesPercentage         float64
# votersPercentage            float64
# subscribedVoters              int64
# totalVoters                   int64
# pre.blankVotes                int64
# pre.blankVotesPercentage    float64
# pre.nullVotes                 int64
# pre.nullVotesPercentage     float64
# pre.votersPercentage        float64
# pre.subscribedVoters          int64
# pre.totalVoters               int64
# Party                        object
# Mandates                      int64
# Percentage                  float64
# validVotesPercentage        float64
# Votes                         int64
# Hondt                         int64
# ...

# %%
from sklearn.preprocessing import LabelEncoder
column=['territoryName','Party']
le=LabelEncoder()
for i in column:
        df[i] = le.fit_transform(df[i].astype(str))

print(df.dtypes)
# Out:
# TimeElapsed                   int64
# territoryName                 int32
# totalMandates                 int64
# availableMandates             int64
# numParishes                   int64
# numParishesApproved           int64
# blankVotes                    int64
# blankVotesPercentage        float64
# nullVotes                     int64
# nullVotesPercentage         float64
# votersPercentage            float64
# subscribedVoters              int64
# totalVoters                   int64
# pre.blankVotes                int64
# pre.blankVotesPercentage    float64
# pre.nullVotes                 int64
# pre.nullVotesPercentage     float64
# pre.votersPercentage        float64
# pre.subscribedVoters          int64
# pre.totalVoters               int64
# Party                         int32
# Mandates                      int64
# Percentage                  float64
# validVotesPercentage        float64
# Votes                         int64
# Hondt                         int64
# ...

# %%
df.columns
# Out:
# Index(['TimeElapsed', 'territoryName', 'totalMandates', 'availableMandates',
#        'numParishes', 'numParishesApproved', 'blankVotes',
#        'blankVotesPercentage', 'nullVotes', 'nullVotesPercentage',
#        'votersPercentage', 'subscribedVoters', 'totalVoters', 'pre.blankVotes',
#        'pre.blankVotesPercentage', 'pre.nullVotes', 'pre.nullVotesPercentage',
#        'pre.votersPercentage', 'pre.subscribedVoters', 'pre.totalVoters',
#        'Party', 'Mandates', 'Percentage', 'validVotesPercentage', 'Votes',
#        'Hondt', 'FinalMandates', 'Day', 'Month', 'Year', 'Hour', 'Minutes',
#        'Seconds'],
#       dtype='object')

# %%
df.shape
# Out:
# (21643, 33)

# %%
column_names = ['TimeElapsed', 'territoryName', 'totalMandates', 'availableMandates',
       'numParishes', 'numParishesApproved', 'blankVotes',
       'blankVotesPercentage', 'nullVotes', 'nullVotesPercentage',
       'votersPercentage', 'subscribedVoters', 'totalVoters', 'pre.blankVotes',
       'pre.blankVotesPercentage', 'pre.nullVotes', 'pre.nullVotesPercentage',
       'pre.votersPercentage', 'pre.subscribedVoters', 'pre.totalVoters',
       'Party', 'Mandates', 'Percentage', 'validVotesPercentage', 'Votes',
       'Hondt','Day', 'Month', 'Year', 'Hour', 'Minutes',
       'Seconds','FinalMandates']

df = df.reindex(columns=column_names)

# %%
df.head()
# Out:
#    TimeElapsed  territoryName  totalMandates  availableMandates  numParishes  \
# 0            0             16              0                226         3092
# 1            0             16              0                226         3092
# 2            0             16              0                226         3092
# 3            0             16              0                226         3092
# 4            0             16              0                226         3092
#
#    numParishesApproved  blankVotes  blankVotesPercentage  nullVotes  \
# 0                 1081        9652                   2.5       8874
# 1                 1081        9652                   2.5       8874
# 2                 1081        9652                   2.5       8874
# 3                 1081        9652                   2.5       8874
# 4                 1081        9652                   2.5       8874
#
#    nullVotesPercentage  ...  validVotesPercentage   Votes  Hondt  Day  Month  \
# ...

# %%
fig, axes = plt.subplots(nrows=8, ncols=4, figsize=(50, 50))
fig.subplots_adjust(hspace=0.8)
fig.suptitle('Election Data',fontsize=20)

for ax, feature, name in zip(axes.flatten(), df.drop('FinalMandates',axis=1).values.T, df.columns.values):
    ax.hist(feature, bins=len(np.unique(df.drop('FinalMandates',axis=1).values.T[0])//2))
    ax.set(title=name[:33].upper())

# %%
df.plot(kind='box',subplots = True,layout=(4,9),figsize = (15,10))
# Out:
# TimeElapsed                     AxesSubplot(0.125,0.71587;0.0731132x0.16413)
# territoryName                AxesSubplot(0.212736,0.71587;0.0731132x0.16413)
# totalMandates                AxesSubplot(0.300472,0.71587;0.0731132x0.16413)
# availableMandates            AxesSubplot(0.388208,0.71587;0.0731132x0.16413)
# numParishes                  AxesSubplot(0.475943,0.71587;0.0731132x0.16413)
# numParishesApproved          AxesSubplot(0.563679,0.71587;0.0731132x0.16413)
# blankVotes                   AxesSubplot(0.651415,0.71587;0.0731132x0.16413)
# blankVotesPercentage         AxesSubplot(0.739151,0.71587;0.0731132x0.16413)
# nullVotes                    AxesSubplot(0.826887,0.71587;0.0731132x0.16413)
# nullVotesPercentage            AxesSubplot(0.125,0.518913;0.0731132x0.16413)
# votersPercentage            AxesSubplot(0.212736,0.518913;0.0731132x0.16413)
# subscribedVoters            AxesSubplot(0.300472,0.518913;0.0731132x0.16413)
# ...

# %%
df.columns
# Out:
# Index(['TimeElapsed', 'territoryName', 'totalMandates', 'availableMandates',
#        'numParishes', 'numParishesApproved', 'blankVotes',
#        'blankVotesPercentage', 'nullVotes', 'nullVotesPercentage',
#        'votersPercentage', 'subscribedVoters', 'totalVoters', 'pre.blankVotes',
#        'pre.blankVotesPercentage', 'pre.nullVotes', 'pre.nullVotesPercentage',
#        'pre.votersPercentage', 'pre.subscribedVoters', 'pre.totalVoters',
#        'Party', 'Mandates', 'Percentage', 'validVotesPercentage', 'Votes',
#        'Hondt', 'Day', 'Month', 'Year', 'Hour', 'Minutes', 'Seconds',
#        'FinalMandates'],
#       dtype='object')

# %%
sns.barplot(x='TimeElapsed',y='FinalMandates',data=df)

# %%
sns.barplot(x='totalMandates',y='FinalMandates',data=df)

# %%
sns.barplot(x='availableMandates',y='FinalMandates',data=df)

# %%
sns.barplot(x='numParishes',y='FinalMandates',data=df)

# %%
sns.barplot(x='numParishesApproved',y='FinalMandates',data=df)

# %%
sns.barplot(x='blankVotes',y='FinalMandates',data=df)

# %%
sns.barplot(x='blankVotesPercentage',y='FinalMandates',data=df)

# %%
sns.barplot(x='nullVotes',y='FinalMandates',data=df)

# %%
sns.barplot(x='nullVotesPercentage',y='FinalMandates',data=df)

# %%
sns.barplot(x='votersPercentage',y='FinalMandates',data=df)

# %%
sns.barplot(x='subscribedVoters',y='FinalMandates',data=df)

# %%
sns.barplot(x='totalVoters',y='FinalMandates',data=df)

# %%
sns.barplot(x='pre.blankVotes',y='FinalMandates',data=df)

# %%
sns.barplot(x='pre.blankVotesPercentage',y='FinalMandates',data=df)

# %%
sns.barplot(x='pre.nullVotes',y='FinalMandates',data=df)

# %%
sns.barplot(x='pre.nullVotesPercentage',y='FinalMandates',data=df)

# %%
sns.barplot(x='pre.votersPercentage',y='FinalMandates',data=df)

# %%
sns.barplot(x='pre.subscribedVoters',y='FinalMandates',data=df)

# %%
sns.barplot(x='pre.totalVoters',y='FinalMandates',data=df)

# %%
sns.barplot(x='Party',y='FinalMandates',data=df)

# %%
sns.barplot(x='Mandates',y='FinalMandates',data=df)

# %%
sns.barplot(x='TimeElapsed',y='FinalMandates',data=df)

# %%
sns.barplot(x='TimeElapsed',y='FinalMandates',data=df)

# %%
sns.barplot(x='Percentage',y='FinalMandates',data=df)

# %%
sns.barplot(x='validVotesPercentage',y='FinalMandates',data=df)

# %%
plt.figure(figsize=(15,8))
sns.barplot(x='Votes',y='FinalMandates',data=df)

# %%
sns.barplot(x='Hondt',y='FinalMandates',data=df)

# %%
sns.barplot(x='Day',y='FinalMandates',data=df)

# %%
sns.barplot(x='Month',y='FinalMandates',data=df)

# %%
sns.barplot(x='Year',y='FinalMandates',data=df)

# %%
sns.barplot(x='Hour',y='FinalMandates',data=df)

# %%
df.skew()
# Out:
# TimeElapsed                 -0.005496
# territoryName               -0.025884
# totalMandates                5.150031
# availableMandates            5.131572
# numParishes                  3.920433
# numParishesApproved          4.238343
# blankVotes                   4.521940
# blankVotesPercentage         0.069627
# nullVotes                    4.520945
# nullVotesPercentage          0.855419
# votersPercentage            -1.158029
# subscribedVoters             4.568797
# totalVoters                  4.541364
# pre.blankVotes               4.551489
# pre.blankVotesPercentage     0.021609
# pre.nullVotes                4.563235
# pre.nullVotesPercentage      1.231109
# pre.votersPercentage        -0.779289
# pre.subscribedVoters         4.565085
# pre.totalVoters              4.548030
# Party                       -0.083536
# Mandates                    16.576658
# Percentage                   2.542328
# validVotesPercentage         2.543122
# Votes                       13.940573
# ...

# %%
skew=['totalMandates', 'availableMandates',
       'numParishes', 'numParishesApproved', 'blankVotes',
        'nullVotes', 'nullVotesPercentage',
       'votersPercentage', 'subscribedVoters', 'totalVoters', 'pre.blankVotes',
       'pre.nullVotes', 'pre.nullVotesPercentage',
       'pre.subscribedVoters', 'pre.totalVoters',
       'Mandates', 'Percentage', 'validVotesPercentage', 'Votes',
       'Hondt', 'Day','Hour',
       'FinalMandates']
for col in skew:
    if df.skew().loc[col]>0.55:
        df[col]=np.log1p(df[col])

# %%
df.skew()
# Out:
# TimeElapsed                -0.005496
# territoryName              -0.025884
# totalMandates               0.673353
# availableMandates           0.739482
# numParishes                 1.724389
# numParishesApproved         0.363008
# blankVotes                 -0.132151
# blankVotesPercentage        0.069627
# nullVotes                  -0.033397
# nullVotesPercentage         0.545046
# votersPercentage           -1.158029
# subscribedVoters            0.019051
# totalVoters                 0.091477
# pre.blankVotes             -0.043120
# pre.blankVotesPercentage    0.021609
# pre.nullVotes              -0.019415
# pre.nullVotesPercentage     0.786357
# pre.votersPercentage       -0.779289
# pre.subscribedVoters        0.021921
# pre.totalVoters             0.094050
# Party                      -0.083536
# Mandates                    4.368206
# Percentage                  1.416849
# validVotesPercentage        1.404150
# Votes                       0.367201
# ...

# %%
from scipy.stats import boxcox
df['numParishes']=boxcox(df['numParishes'],0)

# %%
df['Percentage']=boxcox(df['Percentage'],0)

# %%
df['validVotesPercentage']=boxcox(df['validVotesPercentage'],0)

# %%
df['Day']=boxcox(df['Day'],0.5)

# %%
df.skew()
# Out:
# TimeElapsed                -0.005496
# territoryName              -0.025884
# totalMandates               0.673353
# availableMandates           0.739482
# numParishes                 1.033480
# numParishesApproved         0.363008
# blankVotes                 -0.132151
# blankVotesPercentage        0.069627
# nullVotes                  -0.033397
# nullVotesPercentage         0.545046
# votersPercentage           -1.158029
# subscribedVoters            0.019051
# totalVoters                 0.091477
# pre.blankVotes             -0.043120
# pre.blankVotesPercentage    0.021609
# pre.nullVotes              -0.019415
# pre.nullVotesPercentage     0.786357
# pre.votersPercentage       -0.779289
# pre.subscribedVoters        0.021921
# pre.totalVoters             0.094050
# Party                      -0.083536
# Mandates                    4.368206
# Percentage                  0.177965
# validVotesPercentage        0.172577
# Votes                       0.367201
# ...

# %%
from scipy.stats import zscore
import numpy as np
import pandas as pd
outliers=[]
def detect_outlier(data_1):
    
    threshold=3
    mean_1 = np.mean(data_1)
    std_1 =np.std(data_1)
    
    
    for y in data_1:
        z_score= (y - mean_1)/std_1 
        if np.abs(z_score) > threshold:
            outliers.append(y)
    return outliers

# %%
df.shape #actual rows
# Out:
# (21643, 33)

# %%
df.head()
# Out:
#    TimeElapsed  territoryName  totalMandates  availableMandates  numParishes  \
# 0            0             16            0.0            5.42495     2.084043
# 1            0             16            0.0            5.42495     2.084043
# 2            0             16            0.0            5.42495     2.084043
# 3            0             16            0.0            5.42495     2.084043
# 4            0             16            0.0            5.42495     2.084043
#
#    numParishesApproved  blankVotes  blankVotesPercentage  nullVotes  \
# 0             6.986566    9.175024                   2.5   9.090994
# 1             6.986566    9.175024                   2.5   9.090994
# 2             6.986566    9.175024                   2.5   9.090994
# 3             6.986566    9.175024                   2.5   9.090994
# 4             6.986566    9.175024                   2.5   9.090994
#
#    nullVotesPercentage  ...  validVotesPercentage      Votes     Hondt  \
# ...

# %%
df.dtypes
# Out:
# TimeElapsed                   int64
# territoryName                 int32
# totalMandates               float64
# availableMandates           float64
# numParishes                 float64
# numParishesApproved         float64
# blankVotes                  float64
# blankVotesPercentage        float64
# nullVotes                   float64
# nullVotesPercentage         float64
# votersPercentage            float64
# subscribedVoters            float64
# totalVoters                 float64
# pre.blankVotes              float64
# pre.blankVotesPercentage    float64
# pre.nullVotes               float64
# pre.nullVotesPercentage     float64
# pre.votersPercentage        float64
# pre.subscribedVoters        float64
# pre.totalVoters             float64
# Party                         int32
# Mandates                    float64
# Percentage                  float64
# validVotesPercentage        float64
# Votes                       float64
# Hondt                       float64
# ...

# %%
y=df['FinalMandates'].values

# %%
#independent varaibles
x= df.iloc[:,df.columns!='FinalMandates'].values

# %%
from sklearn.preprocessing import OrdinalEncoder
# Encoding
enc = OrdinalEncoder()
x= enc.fit_transform(x)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x =sc.fit_transform(x)

# %%
x
# Out:
# array([[-1.71470808,  0.98296816, -0.67703029, ..., -0.87449732,
#         -1.01997108,  1.00551351],
#        [-1.71470808,  0.98296816, -0.67703029, ..., -0.87449732,
#         -1.01997108,  1.00551351],
#        [-1.71470808,  0.98296816, -0.67703029, ..., -0.87449732,
#         -1.01997108,  1.00551351],
#        ...,
#        [ 1.69806785,  1.48421407,  0.06077344, ..., -1.60831965,
#          0.48395537, -0.99451672],
#        [ 1.69806785,  1.48421407,  0.06077344, ..., -1.60831965,
#          0.48395537, -0.99451672],
#        [ 1.69806785,  1.48421407,  0.06077344, ..., -1.60831965,
#          0.48395537, -0.99451672]])

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error
from sklearn import linear_model
def maxr2_score(regr,x,y):
    max_r_score=0
    for r_state in range(42,100):
        x_train, x_test, y_train, y_test = train_test_split(x,y,random_state=r_state,test_size=0.20)
        regr.fit(x_train,y_train)
        y_pred=regr.predict(x_test)
        r2_scr=r2_score(y_test,y_pred)
        print('r2_score corresponding to random state:',r_state,'is',r2_scr)
        if r2_scr>max_r_score:
            max_r_score=r2_scr
            final_r_state=r_state

    print('max r2 score corresponding to',final_r_state,'is:',max_r_score)
    return final_r_state

# %%
#lets use Linear Regression and check max_r2_score
from sklearn.linear_model import LinearRegression
lreg=LinearRegression()
r_state=maxr2_score(lreg,x,y)
# Out:
# r2_score corresponding to random state: 42 is 0.9231839198405389
# r2_score corresponding to random state: 43 is 0.9168088794662993
# r2_score corresponding to random state: 44 is 0.9168677574435082
# r2_score corresponding to random state: 45 is 0.916001794148181
# r2_score corresponding to random state: 46 is 0.9135941178039927
# r2_score corresponding to random state: 47 is 0.9191670963067247
# r2_score corresponding to random state: 48 is 0.913229627864283
# r2_score corresponding to random state: 49 is 0.9248656935117191
# r2_score corresponding to random state: 50 is 0.9210086520450662
# r2_score corresponding to random state: 51 is 0.915603173202668
# r2_score corresponding to random state: 52 is 0.9193217108429512
# r2_score corresponding to random state: 53 is 0.9161629091397174
# r2_score corresponding to random state: 54 is 0.9194281937316311
# r2_score corresponding to random state: 55 is 0.9174613474185764
# ...

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsRegressor
neighbors={'n_neighbors':range(1,30)}
knr=KNeighborsRegressor()
gknr=GridSearchCV(knr,neighbors,cv=10)
gknr.fit(x,y)
gknr.best_params_
# Out:
# {'n_neighbors': 1}

# %%
#lets use KNN regression and check max r2 score
knr=KNeighborsRegressor(n_neighbors=1)
r_state=maxr2_score(knr,x,y)
# Out:
# r2_score corresponding to random state: 42 is 0.9886575789859118
# r2_score corresponding to random state: 43 is 0.9865441390396982
# r2_score corresponding to random state: 44 is 0.9875600550737438
# r2_score corresponding to random state: 45 is 0.9890665739654108
# r2_score corresponding to random state: 46 is 0.9879919342259875
# r2_score corresponding to random state: 47 is 0.9893281934439706
# r2_score corresponding to random state: 48 is 0.9868153395772992
# r2_score corresponding to random state: 49 is 0.9910880599269423
# r2_score corresponding to random state: 50 is 0.9866152912723175
# r2_score corresponding to random state: 51 is 0.990465792776738
# r2_score corresponding to random state: 52 is 0.9896579739092548
# r2_score corresponding to random state: 53 is 0.9898772020356666
# r2_score corresponding to random state: 54 is 0.9879031838614784
# r2_score corresponding to random state: 55 is 0.9874460165265545
# ...

# %%
from sklearn.model_selection import cross_val_score
print('Mean r2 score for Linear Regression:',cross_val_score(lreg,x,y,cv=5,scoring='r2').mean())
print('standard deviation in r2 score for Linear Regression: ',cross_val_score(lreg,x,y,cv=5,scoring='r2').std())
print()
print('Mean r2 score for KNN Regression:',cross_val_score(knr,x,y,cv=5,scoring='r2').mean())
print('standard deviation in r2 score for KNeighborsRegressor: ',cross_val_score(knr,x,y,cv=5,scoring='r2').std())
print()
# Out:
# Mean r2 score for Linear Regression: -6.624875306867843e+23
# standard deviation in r2 score for Linear Regression:  1.3249750613735685e+24
#
# Mean r2 score for KNN Regression: 0.9746156119441534
# standard deviation in r2 score for KNeighborsRegressor:  0.04807434435031473

# %%
#lets check lasso regression & find alpha
from sklearn.linear_model import Lasso
lsreg=Lasso()
parameters={'alpha':[0.001,0.01,0.1,1]}
clf=GridSearchCV(lsreg,parameters,cv=10)
clf.fit(x,y)
clf.best_params_
# Out:
# {'alpha': 0.001}

# %%
#lets check max_r2_score with alpha=0.001
lsreg=Lasso(alpha=0.001)
r_state=maxr2_score(lsreg,x,y)
# Out:
# r2_score corresponding to random state: 42 is 0.9212316927665347
# r2_score corresponding to random state: 43 is 0.9146571893672536
# r2_score corresponding to random state: 44 is 0.9142393378111339
# r2_score corresponding to random state: 45 is 0.9135766693166633
# r2_score corresponding to random state: 46 is 0.9104092981748207
# r2_score corresponding to random state: 47 is 0.9168177997780143
# r2_score corresponding to random state: 48 is 0.9114334722057729
# r2_score corresponding to random state: 49 is 0.9225124194667156
# r2_score corresponding to random state: 50 is 0.918910623068532
# r2_score corresponding to random state: 51 is 0.9136413740541548
# r2_score corresponding to random state: 52 is 0.9174524213847879
# r2_score corresponding to random state: 53 is 0.9148670823837227
# r2_score corresponding to random state: 54 is 0.9178561030160565
# r2_score corresponding to random state: 55 is 0.9160380945705178
# ...

# %%
print('Mean r2 score for Lasso Regression:',cross_val_score(lsreg,x,y,cv=5,scoring='r2').mean())
print('standard deviation in r2 score for Lasso Regression: ',cross_val_score(lsreg,x,y,cv=5,scoring='r2').std())
print()
# Out:
# Mean r2 score for Lasso Regression: 0.9138441541981024
# standard deviation in r2 score for Lasso Regression:  0.01688937539413847

# %%
#We tried all the models and till now the best is KNNRegressor
from sklearn.neighbors import KNeighborsRegressor
x_train,x_test,y_train,y_test = train_test_split(x,y,random_state =92 ,test_size = 0.20)
knr=KNeighborsRegressor(n_neighbors=1)
knr.fit(x_train, y_train)
y_pred=knr.predict(x_test)

# %%
import numpy as np
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
print('RMSE:', np.sqrt(mean_squared_error(y_test, y_pred)))
print('r2 score is:',r2_score(y_test, y_pred))
# Out:
# RMSE: 0.05513071601512619
# r2 score is: 0.99291214080924

# %%
from yellowbrick.regressor import PredictionError
model =KNeighborsRegressor(n_neighbors=1)
visualizer = PredictionError(model)

visualizer.fit(x_train, y_train)  # Fit the training data to the visualizer
visualizer.score(x_test, y_test)  # Evaluate the model on the test data
visualizer.show()                 # Finalize and render the figure

# %%
from sklearn.externals import joblib
#save the model 
joblib.dump(knr, 'Project19.obj')
# Out:
# ['Project19.obj']
